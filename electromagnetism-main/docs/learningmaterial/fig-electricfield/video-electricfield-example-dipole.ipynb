# %%
import numpy as np
d = 1.0
x = np.linspace(d,100,1000)
E = 1/(x-d/2)**2 - 1/(x+d/2)**2

# %%
import matplotlib.pyplot as plt
plt.plot(x,E)

# %%
plt.loglog(x,E)

# %%
logx = np.log10(x)
logE = np.log10(E)
plt.plot(logx,logE)

# %%
j = np.where(logx>0.25)
plt.plot(logx[j],logE[j])

# %%
pol = np.polyfit(logx[j],logE[j],1)

# %%
logfit = np.poly1d(pol)
plt.plot(logx,logE,'.r',logx,logfit(logx),':b')
# Out:
# [<matplotlib.lines.Line2D at 0x7fa8a85fae50>,
#  <matplotlib.lines.Line2D at 0x7fa8f86da110>]

# %%
print(pol)
# Out:
# [-3.00909258  0.31681448]
